# %% [markdown]
# <a href="https://colab.research.google.com/github/cynpardede/PCD/blob/main/Pertemuan5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3450807a-009a-46d6-b13b-b57c5f59f934" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3450807a-009a-46d6-b13b-b57c5f59f934">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar grayscale
image = cv2.imread("dede.png", cv2.IMREAD_GRAYSCALE)

# Menampilkan citra asli
plt.figure(figsize=(8,6))
plt.title("Citra Asli")
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# ==========================
# Brightness & Contrast
# ==========================

def adjust_brightness_contrast(image, alpha=1.0, beta=0):
    return cv2.convertScaleAbs(
        image,
        alpha=alpha,
        beta=beta
    )

brightened_image = adjust_brightness_contrast(
    image,
    alpha=1.5,
    beta=50
)

plt.figure(figsize=(8,6))
plt.title("Brightness & Contrast")
plt.imshow(brightened_image, cmap='gray')
plt.axis('off')
plt.show()

# ==========================
# Histogram Equalization
# ==========================

equalized_image = cv2.equalizeHist(image)

plt.figure(figsize=(8,6))
plt.title("Histogram Equalization")
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')
plt.show()

# ==========================
# Gaussian Blur
# ==========================

blurred_image = cv2.GaussianBlur(
    image,
    (5,5),
    0
)

# ==========================
# Sharpening
# ==========================

kernel_sharpen = np.array([
    [0,-1,0],
    [-1,5,-1],
    [0,-1,0]
])

sharpened_image = cv2.filter2D(
    image,
    -1,
    kernel_sharpen
)

plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title("Gaussian Blur")
plt.imshow(blurred_image, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Sharpening")
plt.imshow(sharpened_image, cmap='gray')
plt.axis('off')

plt.show()

print("Praktikum 5 berhasil dijalankan")
# Out:
# Praktikum 5 berhasil dijalankan
